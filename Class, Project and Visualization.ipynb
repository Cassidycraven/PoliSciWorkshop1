# %%
#Dear GOVT 470/670 Students,

#

#Here is the TERRORIST OGRANIZATION Data!

 

#Instructions for this dataset:

 

# Simply copy ALL the lines in this script by pressing

# CTRL+A on Windows or CMND+A on Mac and run the Jupyter cell

# Once you have executed the commands the following objects

# will be created:

 

# Matrices:

#    - Terr_Org_Budget

#    - Attacks

#    - MinutesPlayed

#    - Successful_Attacks

#    - Attack_Attempts

#    - Number_of_Killings

# Lists:

#    - Terr_Organizations

#    - Years

# Dictionaries:

#    - Ydict (year)

#    - Tdict (Terror Organizations)

 

#We will study those concepts inside the course.

## Using this data, we will also study the visualization.

 

# Copyright:

#I utilized Kirill Eremenko's Basketball project data from www.superdatascience.com.

# I generated new variables and values, and

# replaced the data with Terror organizations

## The values are generated(not real)!

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

 

#Import numpy

import numpy as np

#Years

Years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]

Ydict = {"2006":0,"2007":1,"2008":2,"2009":3,"2010":4,"2011":5,"2012":6,"2013":7,"2014":8,"2015":9}

#Terr_Organizations

Terr_Organizations = ["AlQaeda","AlShabab","PKK","AumShinrikyo","ETA","BokoHaram","CPP","LTTE","FARC","MILF"]

Tdict = {"AlQaeda":0,"AlShabab":1,"PKK":2,"AumShinrikyo":3,"ETA":4,"BokoHaram":5,"CPP":6,"LTTE":7,"FARC":8,"MILF":9}

 

#Terr_Org_Budget

AlQaeda_Budget = [1146875,1318750,1590625,1362500,1403475,1806250,2144493,2749149,3053805,3380070]

AlShabab_Budget = [110040,124189,188377,122567,147754,124500,138573,152645,166718,120790]

PKK_Budget = [1462100,1582090,1104150,1241081,1277912,908600,1102500,754000,1107500,1064440]

AumShinrikyo_Budget = [1136480,1494041,1041250,1441081,1577912,1171243,18518574,1945000,224074,2245800]

ETA_Budget = [449360,480620,606174,875800,1420250,960180,1101770,1156360,1213178,1362711]

BokoHaram_Budget = [3348000,423520,124550,1341281,977412,1250400,1202500,11754500,1190670,1064400]

CPP_Budget = [814420,1080160,1035960,1574189,1220450,1340153,1459506,1327468,1268431,1408443]

LTTE_Budget = [1118765,1654354,1137100,1248040,1429880,1102363,1350632,1446930,1532627,719524]

FARC_Budget = [1422456,1320312,1114326,1282800,1254480,556160,6993708,1642500,1632688,1862875]

MILF_Budget = [1031920,1141443,1224250,11410581,1134312,1256530,136070,1482060,1477300,1784660]

#Matrix

Budget = np.array([AlQaeda_Budget, AlShabab_Budget, PKK_Budget, AumShinrikyo_Budget, ETA_Budget, BokoHaram_Budget, CPP_Budget, LTTE_Budget, FARC_Budget, MILF_Budget])

 

#Attacks

AlQaeda_A = [80,77,82,82,73,82,58,78,116,35]

AlShabab_A = [32,27,42,59,46,62,60,32,19,23]

PKK_A = [79,78,75,81,76,79,62,76,77,69]

AumShinrikyo_A = [80,65,77,66,69,77,55,67,77,40]

ETA_A = [82,82,82,79,82,78,54,6,7,11]

BokoHaram_A = [21,39,57,77,70,77,57,74,79,94]

CPP_A = [78,64,80,78,45,80,60,70,62,82]

LTTE_A = [35,35,80,74,82,78,66,81,81,27]

FARC_A = [40,49,66,81,78,81,39,0,2,5]

MILF_A = [75,51,51,79,77,76,49,19,8,3]

#Matrix

Attacks = np.array([AlQaeda_A, AlShabab_A, PKK_A, AumShinrikyo_A, ETA_A, BokoHaram_A, CPP_A, LTTE_A, FARC_A, MILF_A])

 

#Attack Duration

AlQaeda_AD = [277,140,192,360,235,279,212,313,177,107]

AlShabab_AD = [330,239,333,314,286,254,127,242,257,291]

PKK_AD = [331,310,307,304,296,363,226,287,202,293]

AumShinrikyo_AD = [241,246,206,227,234,251,176,242,282,128]

ETA_AD = [301,323,308,282,283,295,200,222,236,123]

BokoHaram_AD = [151,158,225,228,226,295,207,244,231,156]

CPP_AD = [208,233,116,102,112,180,181,235,211,257]

LTTE_AD = [125,115,268,285,323,303,246,311,312,113]

FARC_AD = [105,128,118,100,171,126,175,0,211,130]

MILF_AD = [212,191,194,148,212,213,125,231,175,171]

#Matrix

AttackDuration = np.array([AlQaeda_AD, AlShabab_AD, PKK_AD, AumShinrikyo_AD, ETA_AD, BokoHaram_AD, CPP_AD, LTTE_AD, FARC_AD, MILF_AD])

 

#Successful Attacks

AlQaeda_SA = [68,73,75,80,71,74,57,78,111,26]

AlShabab_SA = [32,16,40,50,45,55,53,25,17,16]

PKK_SA = [75,69,72,71,61,75,61,65,67,64]

AumShinrikyo_SA = [75,61,72,53,61,68,41,66,73,38]

ETA_SA = [78,76,73,69,81,69,46,4,7,7]

BokoHaram_SA = [19,23,57,65,60,52,39,55,72,63]

CPP_SA = [47,38,53,31,31,43,42,41,36,58]

LTTE_SA = [34,33,77,68,79,73,64,77,78,23]

FARC_SA = [38,46,64,74,72,71,32,0,2,5]

MILF_SA = [69,39,43,54,59,62,26,5,7,2]

#Matrix

Successful_Attacks  = np.array([AlQaeda_SA, AlShabab_SA, PKK_SA, AumShinrikyo_SA, ETA_SA, BokoHaram_SA, CPP_SA, LTTE_SA, FARC_SA, MILF_SA])

 

#Attack Attempts

AlQaeda_AA = [113,87,90,112,79,99,76,155,173,73]

AlShabab_AA = [35,39,47,100,86,111,91,52,58,25]

PKK_AA = [83,121,112,93,88,85,116,154,133,79]

AumShinrikyo_AA = [112,153,91,107,102,93,125,109,113,106]

ETA_AA = [88,176,94,119,134,104,72,8,8,13]

BokoHaram_AA = [87,94,107,163,118,106,107,107,153,145]

CPP_AA = [97,71,91,125,67,98,89,85,87,117]

LTTE_AA = [127,147,136,139,166,138,127,143,188,47]

FARC_AA = [46,96,76,120,133,157,65,3,14,7]

MILF_AA = [113,96,97,139,111,134,83,39,11,8]

#Matrix

Attack_Attempts = np.array([AlQaeda_AA, AlShabab_AA, PKK_AA, AumShinrikyo_AA, ETA_AA, BokoHaram_AA, CPP_AA, LTTE_AA, FARC_AA, MILF_AA])

 

#Number of Killings

AlQaeda_NOK = [832,430,323,201,670,278,616,233,383,782]

AlShabab_NOK = [153,126,177,188,161,62,112,110,145,114]

PKK_NOK = [178,132,250,104,228,111,183,136,209,143]

AumShinrikyo_NOK = [212,181,178,104,143,190,145,120,112,66]

ETA_NOK = [122,143,165,114,103,184,113,126,127,346]

BokoHaram_NOK = [152,151,146,346,178,138,125,122,121,328]

CPP_NOK = [128,114,164,178,141,128,119,118,115,154]

LTTE_NOK = [103,43,124,871,472,211,150,220,253,286]

FARC_NOK = [97,57,197,161,119,126,52,0,19,14]

MILF_NOK = [240,197,154,186,145,141,182,163,128,131]

#Matrix

Number_of_Killings = np.array([AlQaeda_NOK, AlShabab_NOK, PKK_NOK, AumShinrikyo_NOK, ETA_NOK, BokoHaram_NOK, CPP_NOK, LTTE_NOK, FARC_NOK, MILF_NOK])

# %%
print(Budget)
# Out:
# [[ 1146875  1318750  1590625  1362500  1403475  1806250  2144493  2749149
#    3053805  3380070]
#  [  110040   124189   188377   122567   147754   124500   138573   152645
#     166718   120790]
#  [ 1462100  1582090  1104150  1241081  1277912   908600  1102500   754000
#    1107500  1064440]
#  [ 1136480  1494041  1041250  1441081  1577912  1171243 18518574  1945000
#     224074  2245800]
#  [  449360   480620   606174   875800  1420250   960180  1101770  1156360
#    1213178  1362711]
#  [ 3348000   423520   124550  1341281   977412  1250400  1202500 11754500
#    1190670  1064400]
#  [  814420  1080160  1035960  1574189  1220450  1340153  1459506  1327468
#    1268431  1408443]
#  [ 1118765  1654354  1137100  1248040  1429880  1102363  1350632  1446930
#    1532627   719524]
#  [ 1422456  1320312  1114326  1282800  1254480   556160  6993708  1642500
#    1632688  1862875]
#  [ 1031920  1141443  1224250 11410581  1134312  1256530   136070  1482060
#    1477300  1784660]]

# %%
print(Attacks)
# Out:
# [[ 80  77  82  82  73  82  58  78 116  35]
#  [ 32  27  42  59  46  62  60  32  19  23]
#  [ 79  78  75  81  76  79  62  76  77  69]
#  [ 80  65  77  66  69  77  55  67  77  40]
#  [ 82  82  82  79  82  78  54   6   7  11]
#  [ 21  39  57  77  70  77  57  74  79  94]
#  [ 78  64  80  78  45  80  60  70  62  82]
#  [ 35  35  80  74  82  78  66  81  81  27]
#  [ 40  49  66  81  78  81  39   0   2   5]
#  [ 75  51  51  79  77  76  49  19   8   3]]

# %%
print(AttackDuration)
# Out:
# [[277 140 192 360 235 279 212 313 177 107]
#  [330 239 333 314 286 254 127 242 257 291]
#  [331 310 307 304 296 363 226 287 202 293]
#  [241 246 206 227 234 251 176 242 282 128]
#  [301 323 308 282 283 295 200 222 236 123]
#  [151 158 225 228 226 295 207 244 231 156]
#  [208 233 116 102 112 180 181 235 211 257]
#  [125 115 268 285 323 303 246 311 312 113]
#  [105 128 118 100 171 126 175   0 211 130]
#  [212 191 194 148 212 213 125 231 175 171]]

# %%
print(Successful_Attacks)
# Out:
# [[ 68  73  75  80  71  74  57  78 111  26]
#  [ 32  16  40  50  45  55  53  25  17  16]
#  [ 75  69  72  71  61  75  61  65  67  64]
#  [ 75  61  72  53  61  68  41  66  73  38]
#  [ 78  76  73  69  81  69  46   4   7   7]
#  [ 19  23  57  65  60  52  39  55  72  63]
#  [ 47  38  53  31  31  43  42  41  36  58]
#  [ 34  33  77  68  79  73  64  77  78  23]
#  [ 38  46  64  74  72  71  32   0   2   5]
#  [ 69  39  43  54  59  62  26   5   7   2]]

# %%
print(Attack_Attempts)
# Out:
# [[113  87  90 112  79  99  76 155 173  73]
#  [ 35  39  47 100  86 111  91  52  58  25]
#  [ 83 121 112  93  88  85 116 154 133  79]
#  [112 153  91 107 102  93 125 109 113 106]
#  [ 88 176  94 119 134 104  72   8   8  13]
#  [ 87  94 107 163 118 106 107 107 153 145]
#  [ 97  71  91 125  67  98  89  85  87 117]
#  [127 147 136 139 166 138 127 143 188  47]
#  [ 46  96  76 120 133 157  65   3  14   7]
#  [113  96  97 139 111 134  83  39  11   8]]

# %%
print(Number_of_Killings)
# Out:
# [[832 430 323 201 670 278 616 233 383 782]
#  [153 126 177 188 161  62 112 110 145 114]
#  [178 132 250 104 228 111 183 136 209 143]
#  [212 181 178 104 143 190 145 120 112  66]
#  [122 143 165 114 103 184 113 126 127 346]
#  [152 151 146 346 178 138 125 122 121 328]
#  [128 114 164 178 141 128 119 118 115 154]
#  [103  43 124 871 472 211 150 220 253 286]
#  [ 97  57 197 161 119 126  52   0  19  14]
#  [240 197 154 186 145 141 182 163 128 131]]

# %%
print(Attacks[0])
# Out:
# [ 80  77  82  82  73  82  58  78 116  35]

# %%
print(Attacks[2])
# Out:
# [79 78 75 81 76 79 62 76 77 69]

# %%
print(Attacks[2][8])
# Out:
# 77

# %%
print(Attacks[2][-2])
# Out:
# 77

# %%
print(Attacks[2,8])
# Out:
# 77

# %% [markdown]
# ---

# %%
print(Number_of_Killings[6])
# Out:
# [128 114 164 178 141 128 119 118 115 154]

# %%
print(Number_of_Killings[6][0])
# Out:
# 128

# %%
dict1 = {'key1':'val1','key2':'val2','key3':'val3'}

# %%
dict1['key2']
# Out:
# 'val2'

# %% [markdown]
# ---

# %% [markdown]
# ### Dicitonaries in our Terr Organization Data

# %%
print(Tdict['ETA'])
# Out:
# 4

# %%
print(Ydict['2008'])
# Out:
# 2

# %%
print(Number_of_Killings[4,2])
# Out:
# 165

# %%
print(Successful_Attacks[8,6])
# Out:
# 32

# %%
print(AttackDuration[7,4])
# Out:
# 323

# %% [markdown]
# ---

# %% [markdown]
# ### Ratio of Successful Attacks
# - Successful_Attacks / Attacks

# %%
Successful_Attacks / Attacks
# Out:
# <ipython-input-22-a845931d5992>:1: RuntimeWarning: invalid value encountered in true_divide
#   Successful_Attacks / Attacks
# array([[0.85      , 0.94805195, 0.91463415, 0.97560976, 0.97260274,
#         0.90243902, 0.98275862, 1.        , 0.95689655, 0.74285714],
#        [1.        , 0.59259259, 0.95238095, 0.84745763, 0.97826087,
#         0.88709677, 0.88333333, 0.78125   , 0.89473684, 0.69565217],
#        [0.94936709, 0.88461538, 0.96      , 0.87654321, 0.80263158,
#         0.94936709, 0.98387097, 0.85526316, 0.87012987, 0.92753623],
#        [0.9375    , 0.93846154, 0.93506494, 0.8030303 , 0.88405797,
#         0.88311688, 0.74545455, 0.98507463, 0.94805195, 0.95      ],
#        [0.95121951, 0.92682927, 0.8902439 , 0.87341772, 0.98780488,
#         0.88461538, 0.85185185, 0.66666667, 1.        , 0.63636364],
#        [0.9047619 , 0.58974359, 1.        , 0.84415584, 0.85714286,
#         0.67532468, 0.68421053, 0.74324324, 0.91139241, 0.67021277],
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
Successful_Attacks / Attacks
# Out:
# array([[0.85      , 0.94805195, 0.91463415, 0.97560976, 0.97260274,
#         0.90243902, 0.98275862, 1.        , 0.95689655, 0.74285714],
#        [1.        , 0.59259259, 0.95238095, 0.84745763, 0.97826087,
#         0.88709677, 0.88333333, 0.78125   , 0.89473684, 0.69565217],
#        [0.94936709, 0.88461538, 0.96      , 0.87654321, 0.80263158,
#         0.94936709, 0.98387097, 0.85526316, 0.87012987, 0.92753623],
#        [0.9375    , 0.93846154, 0.93506494, 0.8030303 , 0.88405797,
#         0.88311688, 0.74545455, 0.98507463, 0.94805195, 0.95      ],
#        [0.95121951, 0.92682927, 0.8902439 , 0.87341772, 0.98780488,
#         0.88461538, 0.85185185, 0.66666667, 1.        , 0.63636364],
#        [0.9047619 , 0.58974359, 1.        , 0.84415584, 0.85714286,
#         0.67532468, 0.68421053, 0.74324324, 0.91139241, 0.67021277],
#        [0.6025641 , 0.59375   , 0.6625    , 0.3974359 , 0.68888889,
#         0.5375    , 0.7       , 0.58571429, 0.58064516, 0.70731707],
# ...

# %%
Successful_Attacks[1,3] / Attacks[1,3]
# Out:
# 0.847457627118644

# %%
np.round(Successful_Attacks[5,9] / Attacks[5,9])
# Out:
# 1.0

# %%
Att_S_Rate = (Successful_Attacks/Attacks)

# %%
print(Att_S_Rate)
# Out:
# [[0.85       0.94805195 0.91463415 0.97560976 0.97260274 0.90243902
#   0.98275862 1.         0.95689655 0.74285714]
#  [1.         0.59259259 0.95238095 0.84745763 0.97826087 0.88709677
#   0.88333333 0.78125    0.89473684 0.69565217]
#  [0.94936709 0.88461538 0.96       0.87654321 0.80263158 0.94936709
#   0.98387097 0.85526316 0.87012987 0.92753623]
#  [0.9375     0.93846154 0.93506494 0.8030303  0.88405797 0.88311688
#   0.74545455 0.98507463 0.94805195 0.95      ]
#  [0.95121951 0.92682927 0.8902439  0.87341772 0.98780488 0.88461538
#   0.85185185 0.66666667 1.         0.63636364]
#  [0.9047619  0.58974359 1.         0.84415584 0.85714286 0.67532468
#   0.68421053 0.74324324 0.91139241 0.67021277]
#  [0.6025641  0.59375    0.6625     0.3974359  0.68888889 0.5375
#   0.7        0.58571429 0.58064516 0.70731707]
#  [0.97142857 0.94285714 0.9625     0.91891892 0.96341463 0.93589744
#   0.96969697 0.95061728 0.96296296 0.85185185]
# ...

# %%
print(Att_S_Rate[6,2])
# Out:
# 0.6625

# %% [markdown]
# ---

# %% [markdown]
# ### Attack Duration for Attacks

# %% [markdown]
# - Attack Duration / Attacks

# %%
print(AttackDuration/Attacks)
# Out:
# [[  3.4625       1.81818182   2.34146341   4.3902439    3.21917808
#     3.40243902   3.65517241   4.01282051   1.52586207   3.05714286]
#  [ 10.3125       8.85185185   7.92857143   5.3220339    6.2173913
#     4.09677419   2.11666667   7.5625      13.52631579  12.65217391]
#  [  4.18987342   3.97435897   4.09333333   3.75308642   3.89473684
#     4.59493671   3.64516129   3.77631579   2.62337662   4.24637681]
#  [  3.0125       3.78461538   2.67532468   3.43939394   3.39130435
#     3.25974026   3.2          3.6119403    3.66233766   3.2       ]
#  [  3.67073171   3.93902439   3.75609756   3.56962025   3.45121951
#     3.78205128   3.7037037   37.          33.71428571  11.18181818]
#  [  7.19047619   4.05128205   3.94736842   2.96103896   3.22857143
#     3.83116883   3.63157895   3.2972973    2.92405063   1.65957447]
#  [  2.66666667   3.640625     1.45         1.30769231   2.48888889
#     2.25         3.01666667   3.35714286   3.40322581   3.13414634]
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Visualization

# %%
import numpy as np

# %%
c

# %%
# I want to get the plot on the Jupyter Notebook page:
# %matplotlib inline

# %%
# Al Qaeda's Budget:
plt.plot(Budget[0])

# %%
# PKK's Budget:
plt.plot(Budget[2])

# %%
# Al Qaeda's Budget:
plt.plot(Budget[0],c="Pink")

# %%
# Al Qaeda's Budget:
plt.plot(Budget[0],c="Pink",ls = 'dotted')

# %%
# Al Qaeda's Budget:
plt.plot(Budget[0],c="Pink",ls = 'dotted', marker = '*')

# %%
# Al Qaeda's Budget:
plt.rcParams['figure.figsize'] = 16,12
plt.plot(Budget[0],c="Purple",ls = 'dotted', marker = '*', ms = '12')
plt.xticks((range(0,10)), Years, rotation = 'vertical')
plt.show()

# %%
# changing the position of the legend > plt.legend(loc= 'upper left', bbox_to_anchor=(1,1))
plt.rcParams['figure.figsize'] = 16,12
plt.plot(Budget[0],c="Blue",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[0])
plt.plot(Budget[1],c="Purple",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[1])
plt.plot(Budget[2],c="Orange",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[2])
plt.plot(Budget[3],c="Pink",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[3])
plt.plot(Budget[4],c="Yellow",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[4])
plt.plot(Budget[5],c="Green",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[5])
plt.plot(Budget[6],c="Black",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[6])
plt.plot(Budget[7],c="Red",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[7])
plt.plot(Budget[8],c="Gray",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[8])
plt.plot(Budget[9],c="Brown",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[9])
plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
plt.xticks((range(0,10)), Years, rotation = 'vertical')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16,12
plt.plot(Attacks[0],c="Blue",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[0])
plt.plot(Attacks[1],c="Purple",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[1])
plt.plot(Attacks[2],c="Orange",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[2])
plt.plot(Attacks[3],c="Pink",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[3])
plt.plot(Attacks[4],c="Yellow",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[4])
plt.plot(Attacks[5],c="Green",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[5])
plt.plot(Attacks[6],c="Black",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[6])
plt.plot(Attacks[7],c="Red",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[7])
plt.plot(Attacks[8],c="Gray",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[8])
plt.plot(Attacks[9],c="Brown",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[9])
plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
plt.xticks((range(0,10)), Years, rotation = 'vertical')
plt.show()

# %% [markdown]
# ## Functions

# %% [markdown]
# # creating our own function

# %% [markdown]
# # def is the command for defining a function

# %%
def myplot():
    plt.rcParams['figure.figsize'] = 16,12
    plt.plot(Attacks[0],c="Blue",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[0])
    plt.plot(Attacks[1],c="Purple",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[1])
    plt.plot(Attacks[2],c="Orange",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[2])
    plt.plot(Attacks[3],c="Pink",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[3])
    plt.plot(Attacks[4],c="Yellow",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[4])
    plt.plot(Attacks[5],c="Green",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[5])
    plt.plot(Attacks[6],c="Black",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[6])
    plt.plot(Attacks[7],c="Red",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[7])
    plt.plot(Attacks[8],c="Gray",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[8])
    plt.plot(Attacks[9],c="Brown",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[9])
    plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
    plt.xticks((range(0,10)), Years, rotation = 'vertical')
    plt.show()

# %%
myplot()

# %%
def myplot(terrlist):
    for name in terrlist:
        plt.plot(Attacks[Tdict[name]] ,c = 'Red', ls = '', ms=12, label = Terr_Organizations[Tdict[name]])
   
    plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
    plt.xticks((range(0,10)), Years, rotation = 'vertical')
    plt.show()

# %%
myplot(['FARC', 'MILF'])

# %% [markdown]
# --- ##Advanced Design

# %%
# we will define a dictionary for colors, line styles, and markers:
# let's copy the list for the colors we have


 #plt.rcParams['figure.figsize'] = 16,12
 #   plt.plot(Attacks[0],c="Blue",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[0])
  #  plt.plot(Attacks[1],c="Purple",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[1])
  #  plt.plot(Attacks[2],c="Orange",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[2])
  #  plt.plot(Attacks[3],c="Pink",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[3])
  #  plt.plot(Attacks[4],c="Yellow",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[4])
 #   plt.plot(Attacks[5],c="Green",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[5])
  #  plt.plot(Attacks[6],c="Black",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[6])
  #  plt.plot(Attacks[7],c="Red",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[7])
  #  plt.plot(Attacks[8],c="Gray",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[8])
  #  plt.plot(Attacks[9],c="Brown",ls = 'dotted', marker = '*', ms = '12', label = Terr_Organizations[9])
  #  plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
 #   plt.xticks((range(0,10)), Years, rotation = 'vertical')
  #  plt.show()










def myplot(terrlist):
    # col = ('key1':'val1', 'key2':'val2')
    # see his notes for making the dictionary right here because I don't have the previous one 
    for name in terrlist:
        plt.plot(Attacks[Tdict[name]] ,c = 'Red', ls = '', ms=12, label = Terr_Organizations[Tdict[name]])
   
    plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
    plt.xticks((range(0,10)), Years, rotation = 'vertical')
    plt.show()

# %%
#same thing but for the line styles 
marker = ()

# %%
def myplot(terrlist):
    # col = ('key1':'val1', 'key2':'val2')
    # see his notes for making the dictionary right here because I don't have the previous one 
    
    for name in terrlist:
        plt.plot(Attacks[Tdict[name]] ,c = 'Red', ls = '', ms=12, label = Terr_Organizations[Tdict[name]])
   
    plt.legend(loc= 'upper left', bbox_to_anchor=(1,0))
    plt.xticks((range(0,10)), Years, rotation = 'vertical')
    plt.show()
